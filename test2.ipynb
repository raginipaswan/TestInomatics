# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-797f97170434> in <cell line: 11>()
#       9 data = {'movieId': [1, 1, 2, 2, 3, 3],
#      10         'rating': [5, 4, 3, 4, 5, 3]}
# ---> 11 df = read_csv('ratings.csv')
#      12
#      13 # Calculate the count of user ratings for each movie
#
# NameError: name 'read_csv' is not defined
